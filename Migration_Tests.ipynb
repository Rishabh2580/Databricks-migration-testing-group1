# %%
# %sql
SELECT COUNT(order_id) AS total_orders,COUNT(DISTINCT order_id) AS distinct_orders
FROM capstone_db.silver_superstore_orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th><th>distinct_orders</th></tr></thead><tbody><tr><td>4683</td><td>4683</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS null_count
FROM capstone_db.silver_superstore_orders
WHERE order_id IS NULL
OR customer_id IS NULL
OR sales IS NULL
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>null_count</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
# %sql
Select Count(*)
from
capstone_db.bronze_superstore_orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Count(*)</th></tr></thead><tbody><tr><td>9996</td></tr></tbody></table></div>

# %%
report = [
    ("Row Count Validation", "PASS"),
    ("Duplicate validation", "PASS"),
    ("Null Validation", "PASS"),
]    
df_report = spark.createDataFrame(report, ["Test_Name", "Status"])
display(df_report)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Test_Name</th><th>Status</th></tr></thead><tbody><tr><td>Row Count Validation</td><td>False</td></tr><tr><td>Duplicate validation</td><td>False</td></tr><tr><td>Null Validation</td><td>PASS</td></tr></tbody></table></div>

# %%
df_report.write \
    .mode("overwrite") \
    .saveAsTable("capstone_db.data_validation_report")

# %%
# %sql
Select * from capstone_db.data_validation_report
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Test_Name</th><th>Status</th></tr></thead><tbody><tr><td>Row Count Validation</td><td>False</td></tr><tr><td>Duplicate validation</td><td>False</td></tr><tr><td>Null Validation</td><td>PASS</td></tr></tbody></table></div>
