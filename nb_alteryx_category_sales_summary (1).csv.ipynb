# %%
# %python
spark.conf.set("fs.azure.account.key.stmigtestdev01.blob.core.windows.net","FUpXyJbyH1bClvXebH+fUxApQG6DOo6eKn4eAnpzu8+HxJVAzQwLFU2UI3yJq0ZZhrFDLp1YZWlB+AStJB0xSA==")

# %%
# %python
df_orders = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
.load("wasbs://raw@stmigtestdev01.blob.core.windows.net/alteryx_category_sales_summary (1).csv")
display(df_orders)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>total_sales</th><th>order_count</th></tr></thead><tbody><tr><td>Furniture</td><td>719712.4551</td><td>1693</td></tr><tr><td>Office Supplies</td><td>698113.159</td><td>3626</td></tr><tr><td>Technology</td><td>814148.419</td><td>1496</td></tr></tbody></table></div>

# %%
# %python
df_orders.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("capstone_alteryx_category_sales_summary_1")

# %%
# %sql SHOW TABLES
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>alteryx_region_customer_sales</td><td>false</td></tr><tr><td>default</td><td>capstone_alteryx_category_sales_summary_1</td><td>false</td></tr><tr><td></td><td>_sqldf</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
Select * from capstone_alteryx_category_sales_summary_1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>total_sales</th><th>order_count</th></tr></thead><tbody><tr><td>Furniture</td><td>719712.4551</td><td>1693</td></tr><tr><td>Office Supplies</td><td>698113.159</td><td>3626</td></tr><tr><td>Technology</td><td>814148.419</td><td>1496</td></tr></tbody></table></div>
